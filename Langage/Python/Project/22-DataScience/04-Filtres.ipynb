# %%
import pandas as pd
df = pd.read_csv("data.csv")

# %%
df["gender"] == "Male"
# Out:
# 0       True
# 1      False
# 2       True
# 3      False
# 4       True
#        ...
# 995    False
# 996    False
# 997     True
# 998     True
# 999    False
# Name: gender, Length: 1000, dtype: bool

# %%
male_filter = df["gender"] == "Male"
df[male_filter]
# Out:
#       id        date first_name   last_name                       email  \
# 0      1  03/28/2021    Marylin      Alders        malders0@shop-pro.jp
# 2      3  03/17/2021        Erl  Kilminster       ekilminster2@etsy.com
# 4      5  03/24/2021      Kanya     Beasant         kbeasant4@jigsy.com
# 7      8  03/08/2021       Codi     Feasley            cfeasley7@ed.gov
# 8      9  03/09/2021     Waylon    Heersema       wheersema8@tumblr.com
# ..   ...         ...        ...         ...                         ...
# 991  992  03/07/2021      Elihu       Crush       ecrushrj@berkeley.edu
# 992  993  03/04/2021    Maurene  Guilloneau      mguilloneaurk@about.me
# 993  994  03/22/2021      Ossie      Snelle            osnellerl@nhs.uk
# 997  998  03/13/2021      Betty    Stickels  bstickelsrp@cloudflare.com
# 998  999  03/17/2021    Paquito       Tesoe      ptesoerq@rakuten.co.jp
#
#     gender       ip_address        country price_paid   tax
# 0     Male    160.119.8.119         Canada      $5.36   NaN
# 2     Male    213.8.101.145  United States      $3.73  20.0
# 4     Male  106.252.162.233        Morocco      $9.24  20.0
# 7     Male   26.190.191.249         France      $3.01  20.0
# 8     Male   63.242.174.112         Canada      $3.70  20.0
# ..     ...              ...            ...        ...   ...
# 991   Male    174.38.173.53        Morocco      $5.05  20.0
# 992   Male   108.73.141.204         France      $9.19   NaN
# 993   Male   230.187.67.246         France      $4.31   NaN
# 997   Male     199.80.60.87  United States      $7.54  20.0
# 998   Male      0.183.63.11  United States      $5.81   NaN
#
# [438 rows x 10 columns]

# %%
country_filter = df["country"].isin(("France", "Canada"))
df[country_filter]
# Out:
#        id        date first_name   last_name                      email  \
# 0       1  03/28/2021    Marylin      Alders       malders0@shop-pro.jp
# 1       2  03/19/2021      Hinda    Harridge         hharridge1@gnu.org
# 6       7  03/14/2021        Ava     Kencott         akencott6@phoca.cz
# 7       8  03/08/2021       Codi     Feasley           cfeasley7@ed.gov
# 8       9  03/09/2021     Waylon    Heersema      wheersema8@tumblr.com
# ..    ...         ...        ...         ...                        ...
# 992   993  03/04/2021    Maurene  Guilloneau     mguilloneaurk@about.me
# 993   994  03/22/2021      Ossie      Snelle           osnellerl@nhs.uk
# 994   995  03/17/2021   Carolyne    Bruntjen  cbruntjenrm@reference.com
# 995   996  03/24/2021       Duff      Errigo       derrigorn@elpais.com
# 999  1000  03/23/2021   Rochelle    Pringuer      rpringuerrr@house.gov
#
#      gender      ip_address country price_paid   tax
# 0      Male   160.119.8.119  Canada      $5.36   NaN
# 1    Female  210.51.172.132  Canada      $8.32   NaN
# 6    Female   118.251.45.43  Canada      $6.29   NaN
# 7      Male  26.190.191.249  France      $3.01  20.0
# 8      Male  63.242.174.112  Canada      $3.70  20.0
# ..      ...             ...     ...        ...   ...
# 992    Male  108.73.141.204  France      $9.19   NaN
# 993    Male  230.187.67.246  France      $4.31   NaN
# 994  Female     7.29.168.78  France      $5.68  20.0
# 995  Female  193.84.247.144  France      $3.63   NaN
# 999     NaN  170.193.249.83  Canada      $8.01  20.0
#
# [569 rows x 10 columns]

# %%
df[df["price_paid"]>5]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\martin.sion\Local\Documentation\Langage\Python\Project\22-DataScience\04-Filtres.ipynb Cell 5' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/martin.sion/Local/Documentation/Langage/Python/Project/22-DataScience/04-Filtres.ipynb#ch0000016?line=0'>1</a> df[df["price_paid"]>5]
#
# File c:\Users\martin.sion\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\ops\common.py:70, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      <a href='file:///c%3A/Users/martin.sion/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/ops/common.py?line=65'>66</a>             return NotImplemented
#      <a href='file:///c%3A/Users/martin.sion/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/ops/common.py?line=67'>68</a> other = item_from_zerodim(other)
# ---> <a href='file:///c%3A/Users/martin.sion/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/ops/common.py?line=69'>70</a> return method(self, other)
#
# File c:\Users\martin.sion\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\arraylike.py:56, in OpsMixin.__gt__(self, other)
#      <a href='file:///c%3A/Users/martin.sion/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/arraylike.py?line=53'>54</a> @unpack_zerodim_and_defer("__gt__")
#      <a href='file:///c%3A/Users/martin.sion/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/arraylike.py?line=54'>55</a> def __gt__(self, other):
# ---> <a href='file:///c%3A/Users/martin.sion/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/arraylike.py?line=55'>56</a>     return self._cmp_method(other, operator.gt)
#
# File c:\Users\martin.sion\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\series.py:5623, in Series._cmp_method(self, other, op)
#    <a href='file:///c%3A/Users/martin.sion/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/series.py?line=5619'>5620</a> rvalues = extract_array(other, extract_numpy=True, extract_range=True)
#    <a href='file:///c%3A/Users/martin.sion/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/series.py?line=5621'>5622</a> with np.errstate(all="ignore"):
# -> <a href='file:///c%3A/Users/martin.sion/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/series.py?line=5622'>5623</a>     res_values = ops.comparison_op(lvalues, rvalues, op)
#    <a href='file:///c%3A/Users/martin.sion/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/series.py?line=5624'>5625</a> return self._construct_result(res_values, name=res_name)
#
# File c:\Users\martin.sion\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\ops\array_ops.py:283, in comparison_op(left, right, op)
#     <a href='file:///c%3A/Users/martin.sion/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/ops/array_ops.py?line=279'>280</a>     return invalid_comparison(lvalues, rvalues, op)
#     <a href='file:///c%3A/Users/martin.sion/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/ops/array_ops.py?line=281'>282</a> elif is_object_dtype(lvalues.dtype) or isinstance(rvalues, str):
# --> <a href='file:///c%3A/Users/martin.sion/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/ops/array_ops.py?line=282'>283</a>     res_values = comp_method_OBJECT_ARRAY(op, lvalues, rvalues)
#     <a href='file:///c%3A/Users/martin.sion/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/ops/array_ops.py?line=284'>285</a> else:
#     <a href='file:///c%3A/Users/martin.sion/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/ops/array_ops.py?line=285'>286</a>     res_values = _na_arithmetic_op(lvalues, rvalues, op, is_cmp=True)
#
# File c:\Users\martin.sion\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\ops\array_ops.py:73, in comp_method_OBJECT_ARRAY(op, x, y)
#      <a href='file:///c%3A/Users/martin.sion/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/ops/array_ops.py?line=70'>71</a>     result = libops.vec_compare(x.ravel(), y.ravel(), op)
#      <a href='file:///c%3A/Users/martin.sion/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/ops/array_ops.py?line=71'>72</a> else:
# ---> <a href='file:///c%3A/Users/martin.sion/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/ops/array_ops.py?line=72'>73</a>     result = libops.scalar_compare(x.ravel(), y, op)
#      <a href='file:///c%3A/Users/martin.sion/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/ops/array_ops.py?line=73'>74</a> return result.reshape(x.shape)
#
# File c:\Users\martin.sion\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\_libs\ops.pyx:107, in pandas._libs.ops.scalar_compare()
#
# TypeError: '>' not supported between instances of 'str' and 'int'

# %%
df_test = df.copy()
df_test.price_paid = df_test.price_paid.apply(lambda x: x.replace("$", ""))
df_test.price_paid = df_test.price_paid.astype(float)
df_test[df_test["price_paid"] >= 5.0]
# Out:
#        id        date first_name   last_name                       email  \
# 0       1  03/28/2021    Marylin      Alders        malders0@shop-pro.jp
# 1       2  03/19/2021      Hinda    Harridge          hharridge1@gnu.org
# 4       5  03/24/2021      Kanya     Beasant         kbeasant4@jigsy.com
# 5       6  03/25/2021      Titos  Braybrooke        tbraybrooke5@umn.edu
# 6       7  03/14/2021        Ava     Kencott          akencott6@phoca.cz
# ..    ...         ...        ...         ...                         ...
# 992   993  03/04/2021    Maurene  Guilloneau      mguilloneaurk@about.me
# 994   995  03/17/2021   Carolyne    Bruntjen   cbruntjenrm@reference.com
# 997   998  03/13/2021      Betty    Stickels  bstickelsrp@cloudflare.com
# 998   999  03/17/2021    Paquito       Tesoe      ptesoerq@rakuten.co.jp
# 999  1000  03/23/2021   Rochelle    Pringuer       rpringuerrr@house.gov
#
#      gender       ip_address        country  price_paid   tax
# 0      Male    160.119.8.119         Canada        5.36   NaN
# 1    Female   210.51.172.132         Canada        8.32   NaN
# 4      Male  106.252.162.233        Morocco        9.24  20.0
# 5    Female   173.100.21.179  United States        5.82   NaN
# 6    Female    118.251.45.43         Canada        6.29   NaN
# ..      ...              ...            ...         ...   ...
# 992    Male   108.73.141.204         France        9.19   NaN
# 994  Female      7.29.168.78         France        5.68  20.0
# 997    Male     199.80.60.87  United States        7.54  20.0
# 998    Male      0.183.63.11  United States        5.81   NaN
# 999     NaN   170.193.249.83         Canada        8.01  20.0
#
# [696 rows x 10 columns]
